# %% [markdown]
# # Data Analysis - Topic Modeling

# %% [markdown]
# ## Introduction:
#
# Embarking on the exploration of prevalent topics within the climate change discourse on Twitter, I employ an advanced machine learning technique, specifically BERTopic. This approach aims to unravel nuanced themes through data analysis and visualization methods, shedding light on the most discussed subjects in the Twitter community.
#
# Furthermore, an exploration into the temporal dynamics of these identified topics takes shape. Employing a variety of visualization methods, this analysis shows the evolving trends of climate change discussions over time, offering valuable insights into the dynamic nature of discussion on Twitter.
#
# Subsequent analyses extend to probing the correlation between public sentiment, extreme natural events, and the release of environmental policies. The observed peaks and fluctuations in the graphical representations serve as crucial indicators for predicting relationships between public perception and external factors such as extreme weather occurrences and policy releases.

# %% [markdown]
# ## Import fundamental packages to load dataset
#
# 1. import panda
# 2. read dataset from my github raw data link

# %%
import pandas as pd
import io

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Rising-Stars-by-Sunshine/STATS201-PS2-Jenny/main/Data/processed%20data/cleaned_dataset.csv")
df
# Out:
#                 UserScreenName          UserName                 Timestamp  \
# 0               Lauren Boebert    @laurenboebert  2022-01-17T23:32:38.000Z
# 1                    Catherine    @catherine___c  2022-01-17T22:54:02.000Z
# 2                   king Keith      @KaConfessor  2022-01-17T23:51:41.000Z
# 3     PETRIFIED CLIMATE PARENT   @climate_parent  2022-01-17T21:42:04.000Z
# 4               Thomas Speight       @Thomas_Sp8  2022-01-17T21:10:40.000Z
# ...                        ...               ...                       ...
# 9033      Dr Srijana Mitra Das    @srijanapiya17  2022-07-18T12:08:28.000Z
# 9034       1%_Better_Every_Day         @jh336405  2022-07-18T00:33:20.000Z
# 9035           David Schechter   @DavidSchechter  2022-07-18T21:13:13.000Z
# 9036             Daily Climate  @TheDailyClimate  2022-07-18T10:15:09.000Z
# 9037          Robot Enthusiast     @robothusiast  2022-07-18T16:32:53.000Z
#
#                                                    Text  \
# 0             Lauren Boebert\n@laurenboebert\n·\nJan 18
# 1                  Catherine\n@catherine___c\n·\nJan 17
# 2                   king Keith\n@KaConfessor\n·\nJan 18
# 3     PETRIFIED CLIMATE PARENT\n@climate_parent\n·\n...
# 4                Thomas Speight\n@Thomas_Sp8\n·\nJan 17
# ...                                                 ...
# 9033    Dr Srijana Mitra Das\n@srijanapiya17\n·\nJul 18
# 9034          1%_Better_Every_Day\n@jh336405\n·\nJul 18
# 9035        David Schechter\n@DavidSchechter\n·\nJul 18
# 9036         Daily Climate\n@TheDailyClimate\n·\nJul 18
# 9037         Robot Enthusiast\n@robothusiast\n·\nJul 18
#
#                                           Embedded_text Emojis Comments  \
# 0     The only solution I’ve ever heard the Left pro...    NaN    1,683
# 1     Climate change doesn’t cause volcanic eruption...    NaN      158
# 2     Vaccinated tennis ball boy collapses in the te...    NaN       24
# 3     North America has experienced an average winte...    NaN       15
# 4     They're gonna do the same with Climate Change ...      🅾        4
# ...                                                 ...    ...      ...
# 9033  #ClimateChange is now the greatest story on Ea...    NaN        2
# 9034  Replying to \n@jh336405\n @acuna_r\n and 41 ot...  💯 💯 🌏        4
# 9035  While Texans are being asked to use less elect...    NaN        3
# 9036  Sea levels are rising, and communities are scr...    NaN      NaN
# 9037  UTS creates algae-analysing robot to combat cl...    NaN      NaN
#
#       Likes Retweets                                         Image link  \
# 0     2,259    11.7K                                                 []
# 1        64      762                                                 []
# 2       118      159  ['https://pbs.twimg.com/ext_tw_video_thumb/148...
# 3        50      158                                                 []
# 4        24      127  ['https://pbs.twimg.com/profile_images/1544171...
# ...     ...      ...                                                ...
# 9033     16       24  ['https://pbs.twimg.com/profile_images/5140754...
# 9034    NaN      NaN  ['https://pbs.twimg.com/profile_images/1442412...
# 9035     14       23  ['https://pbs.twimg.com/card_img/1549138950475...
# 9036      3      NaN  ['https://pbs.twimg.com/card_img/1547862999808...
# 9037    NaN      NaN  ['https://pbs.twimg.com/card_img/1549069752219...
#
#                                               Tweet URL  \
# 0     https://twitter.com/laurenboebert/status/14832...
# 1     https://twitter.com/catherine___c/status/14832...
# 2     https://twitter.com/KaConfessor/status/1483225...
# 3     https://twitter.com/climate_parent/status/1483...
# 4     https://twitter.com/Thomas_Sp8/status/14831850...
# ...                                                 ...
# 9033  https://twitter.com/srijanapiya17/status/15490...
# 9034  https://twitter.com/jh336405/status/1548828230...
# 9035  https://twitter.com/DavidSchechter/status/1549...
# 9036  https://twitter.com/TheDailyClimate/status/154...
# 9037  https://twitter.com/robothusiast/status/154906...
#
#                  mentioned_users  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                      joeywreck
# ...                          ...
# 9033       DrSimEvans,DrSimEvans
# 9034  jh336405,acuna_r,rahmstorf
# 9035               GregAbbott_TX
# 9036              NHBulletinNews
# 9037                         NaN
#
#                                           partial_clean  \
# 0     The only solution I’ve ever heard the Left pro...
# 1     Climate change doesn’t cause volcanic eruption...
# 2     Vaccinated tennis ball boy collapses in the te...
# 3     North America has experienced an average winte...
# 4     They're gonna do the same with Climate Change ...
# ...                                                 ...
# 9033  #ClimateChange is now the greatest story on Ea...
# 9034  Replying to and 41 others And Stefan Rahmstorf...
# 9035  While Texans are being asked to use less elect...
# 9036  Sea levels are rising, and communities are scr...
# 9037  UTS creates algae-analysing robot to combat cl...
#
#                                            cleaned_text
# 0     the only solution ive ever heard the left prop...
# 1       climate change doesnt cause volcanic eruptions
# 2     vaccinated tennis ball boy collapses in the te...
# 3     north america has experienced an average winte...
# 4     they re gonna do the same with climate change ...
# ...                                                 ...
# 9033  climatechange is now the greatest story on ear...
# 9034  replying to and others and stefan rahmstorf co...
# 9035  while texans are being asked to use less elect...
# 9036  sea levels are rising and communities are scra...
# 9037  uts creates algae analysing robot to combat cl...
#
# [9038 rows x 14 columns]

# %% [markdown]
# ## Install and import topic modeling packages and visualization tools

# %%
# !pip install bertopic
# !pip install gensim
# !pip install wordcloud
# !pip install matplotlib
# Out:
# Collecting bertopic
#   Downloading bertopic-0.16.0-py2.py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.23.5)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 22.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.1)
# Collecting sentence-transformers>=0.4.1 (from bertopic)
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 10.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Collecting cython<3,>=0.27 (from hdbscan>=0.8.29->bertopic)
#   Using cached Cython-0.29.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.11.4)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.35.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.16.0+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Collecting sentencepiece (from sentence-transformers>=0.4.1->bertopic)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 32.4 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.19.4)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.11-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.41.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.7)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039170 sha256=5177e806a7d667773a64e6c78f0019e500cbdc61716313e79de8aff96cf3bed6
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=3fb5866cb5a24f45d2aa26ae187ad30873ebaec0f606e037d8cff7d58db3c0b7
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=664eb3c144d73cefefc99d8daf9b84de3ea8e4d5a5eeb987e4283e7f65f66783
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
# Successfully built hdbscan sentence-transformers umap-learn
# Installing collected packages: sentencepiece, cython, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.6
#     Uninstalling Cython-3.0.6:
#       Successfully uninstalled Cython-3.0.6
# Successfully installed bertopic-0.16.0 cython-0.29.36 hdbscan-0.8.33 pynndescent-0.5.11 sentence-transformers-2.2.2 sentencepiece-0.1.99 umap-learn-0.5.5
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import io
from bertopic import BERTopic
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel
from wordcloud import WordCloud

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
from bertopic.representation import KeyBERTInspired
from bertopic.representation import PartOfSpeech
from bertopic.representation import MaximalMarginalRelevance

# %% [markdown]
# ## Apply BERT model to analyze the dataset
#
# Attention: it takes a few minutes to load the data.

# %%
vectorizer_model = CountVectorizer(stop_words="english")
main_representation = KeyBERTInspired()
aspect_model1 = PartOfSpeech("en_core_web_sm")
aspect_model2 = [KeyBERTInspired(top_n_words=30), MaximalMarginalRelevance(diversity=.5)]
representation_model = {
   "Main": main_representation,
   "Aspect1":  aspect_model1,
   "Aspect2":  aspect_model2
}
model = BERTopic(verbose=True,vectorizer_model=vectorizer_model,representation_model=representation_model,calculate_probabilities=True)
doc = df.partial_clean.to_list()
timestamps = df.Timestamp	.to_list()
topics, probs = model.fit_transform(doc)
# Out:
# 2023-12-13 10:22:01,801 - BERTopic - Embedding - Transforming documents to embeddings.
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Batches:   0%|          | 0/283 [00:00<?, ?it/s]
# 2023-12-13 10:28:41,803 - BERTopic - Embedding - Completed ✓
# 2023-12-13 10:28:41,805 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2023-12-13 10:29:33,238 - BERTopic - Dimensionality - Completed ✓
# 2023-12-13 10:29:33,240 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2023-12-13 10:29:39,961 - BERTopic - Cluster - Completed ✓
# 2023-12-13 10:29:39,975 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2023-12-13 10:32:29,698 - BERTopic - Representation - Completed ✓

# %%
probs_df=pd.DataFrame(probs)
probs_df['main percentage'] = pd.DataFrame({'max': probs_df.max(axis=1)})

display(probs_df)
# Out:
#                   0              1              2              3  \
# 0      2.106860e-03   2.076819e-03   3.380976e-03   3.805252e-03
# 1      2.583081e-03   2.307738e-03   1.906871e-02   3.036820e-03
# 2      2.537047e-03   2.454773e-03   6.740005e-03   2.757704e-03
# 3      3.945190e-03   3.333326e-03   6.303440e-03   3.693209e-03
# 4     1.432389e-307  1.420354e-307  3.355639e-307  1.617886e-307
# ...             ...            ...            ...            ...
# 9033   2.423301e-03   2.415128e-03   2.920496e-03   2.386583e-03
# 9034   2.793664e-03   2.490613e-03   1.165527e-02   3.481822e-03
# 9035   6.130316e-03   5.189162e-03   4.515424e-03   6.427443e-03
# 9036   3.032414e-03   2.845349e-03   2.128136e-03   2.381743e-03
# 9037  1.727369e-307  2.705092e-307  2.163120e-307  2.260220e-307
#
#                   4              5              6              7  \
# 0      2.908366e-03   3.346582e-03   1.749047e-03   2.074355e-03
# 1      2.408651e-03   3.609081e-03   2.079689e-03   2.239368e-03
# 2      2.328275e-03   5.630932e-03   2.024713e-03   2.383629e-03
# 3      2.963641e-03   3.177850e-03   3.271716e-03   3.158124e-03
# 4     1.353547e-307  3.660893e-307  1.141072e-307  1.362614e-307
# ...             ...            ...            ...            ...
# 9033   2.134628e-03   2.353336e-03   2.216309e-03   2.349752e-03
# 9034   2.868584e-03   4.053065e-03   2.283643e-03   2.470368e-03
# 9035   4.790298e-03   3.592751e-03   5.059571e-03   5.035845e-03
# 9036   2.258360e-03   1.699483e-03   3.372596e-03   2.650286e-03
# 9037  2.240884e-307  1.969735e-307  2.283108e-307  1.806751e-307
#
#                   8              9  ...            121            122  \
# 0      3.421267e-03   3.589541e-03  ...   2.469932e-03   1.938443e-03
# 1      5.840540e-03   5.182761e-03  ...   2.803620e-03   2.151005e-03
# 2      2.513738e-02   4.420387e-03  ...   2.750566e-03   2.264676e-03
# 3      4.104789e-03   5.811131e-03  ...   3.195588e-03   2.977794e-03
# 4      1.000000e+00  2.242752e-307  ...  1.523481e-307  1.323880e-307
# ...             ...            ...  ...            ...            ...
# 9033   2.818512e-03   5.952349e-03  ...   2.343565e-03   2.051627e-03
# 9034   5.898396e-03   6.900145e-03  ...   3.432223e-03   2.312249e-03
# 9035   3.824480e-03   5.029044e-03  ...   3.918982e-03   4.579246e-03
# 9036   1.823373e-03   3.137329e-03  ...   2.158056e-03   2.237471e-03
# 9037  2.341450e-307  3.061260e-307  ...  1.849298e-307  2.283752e-307
#
#                 123            124            125            126  \
# 0      5.910877e-03   4.135478e-03   4.235448e-03   2.145951e-03
# 1      3.239657e-03   3.777361e-03   2.078591e-02   2.081066e-03
# 2      3.241028e-03   3.709827e-03   7.724892e-03   2.764999e-03
# 3      3.603611e-03   4.377097e-03   8.296030e-03   2.232142e-03
# 4     1.933154e-307  2.052309e-307  3.720351e-307  1.685245e-307
# ...             ...            ...            ...            ...
# 9033   2.861937e-03   4.906866e-03   4.086104e-03   1.743728e-03
# 9034   3.915323e-03   4.680114e-03   1.373738e-02   2.415635e-03
# 9035   5.815367e-03   5.164297e-03   5.273743e-03   2.815203e-03
# 9036   2.415055e-03   2.979176e-03   2.509055e-03   1.538255e-03
# 9037  3.028064e-307   1.000000e+00  3.038077e-307  1.664917e-307
#
#                 127            128            129  main percentage
# 0      4.146746e-03   3.669829e-03   2.465067e-03         0.012174
# 1      3.314942e-03   3.036407e-03   2.770118e-03         0.035294
# 2      3.940134e-03   3.276203e-03   2.620119e-03         0.025137
# 3      3.293833e-03   4.045920e-03   4.544460e-03         0.065714
# 4     2.361308e-307  1.845097e-307  1.459550e-307         1.000000
# ...             ...            ...            ...              ...
# 9033   2.591444e-03   4.533256e-03   3.641909e-03         0.006953
# 9034   3.849900e-03   3.571065e-03   3.096660e-03         0.106865
# 9035   4.343824e-03   6.152276e-03   6.880853e-03         0.170664
# 9036   1.987915e-03   3.346789e-03   4.845337e-03         0.117507
# 9037  2.213135e-307  3.315854e-307  3.938244e-307         1.000000
#
# [9038 rows x 131 columns]

# %% [markdown]
# ## Visualizate the results

# %%
model.get_topic_info()
model.get_topic(0)
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="53771b36-13d9-45d8-b52b-a06f62f0cd59" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53771b36-13d9-45d8-b52b-a06f62f0cd59")) {                    Plotly.newPlot(                        "53771b36-13d9-45d8-b52b-a06f62f0cd59",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.3970503509044647,0.4050094485282898,0.44217365980148315,0.4725210666656494,0.4968559741973877],"y":["aus  ","politicians  ","australians  ","ausvotes  ","auspol  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.47831958532333374,0.49731260538101196,0.5029640197753906,0.5051172375679016,0.5451684594154358],"y":["farms  ","crops  ","climate  ","agricultural  ","agriculture  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.2735062539577484,0.2774932384490967,0.2844216227531433,0.4583570063114166,0.6056534647941589],"y":["disaster  ","conversation  ","change  ","replying  ","climate  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.3404988646507263,0.34874093532562256,0.34895458817481995,0.39938533306121826,0.5519741773605347],"y":["cars  ","tesla  ","emissions  ","ev  ","volvo  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.3705917000770569,0.38449007272720337,0.38700932264328003,0.3872227370738983,0.4405773878097534],"y":["alberta  ","trudeau  ","ontario  ","trudeaus  ","emissions  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.4067740738391876,0.41667118668556213,0.42147529125213623,0.4237995147705078,0.4560096859931946],"y":["voting  ","democratic  ","republicans  ","ballot  ","filibuster  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.5270901322364807,0.5329463481903076,0.5540832877159119,0.5869584083557129,0.6103489398956299],"y":["forest  ","trees  ","deforestation  ","forests  ","forestry  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.4201057255268097,0.4360758066177368,0.44741952419281006,0.4676610827445984,0.5221331715583801],"y":["climate  ","islands  ","fijis  ","fiji  ","pacific  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c1 ...

# %%
import matplotlib.pyplot as plt

# %%
def create_wordcloud(model, topic):
    text = {word: value for word, value in model.get_topic(topic)}
    wc = WordCloud(background_color="white", max_words=2000)
    wc.generate_from_frequencies(text)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# Show wordcloud for one theme
create_wordcloud(model, topic=1)

# %% [markdown]
# Attention: it may take ~20mins to load

# %%
topics_over_time = model.topics_over_time(doc, timestamps, nr_bins=20)
# Out:
# 20it [09:00, 27.05s/it]

# %%
model.visualize_topics_over_time(topics_over_time, topics=[0,1,2,3,4,5])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ef4e2bc4-e563-4499-89b2-41fa18e0440e" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef4e2bc4-e563-4499-89b2-41fa18e0440e")) {                    Plotly.newPlot(                        "ef4e2bc4-e563-4499-89b2-41fa18e0440e",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: auspol, australians, australia, climatecriminal, australian","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: tasmania, auspol, canberra, perth, austerity","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: auspol, australians, politics, australian, nzpol","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: auspol, abbott, australians, aussies, australias","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: aussies, auspol, australians, australiainstituteorgau, aus","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: disasters, auspol, floods, disaster, australians","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: climate, emissions, australians, auspol, australias","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: auspol, australians, australias, australia, australian","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: auspol, climate, emissions, australians, aussies","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: independents, independentsday, auspol, election, australians","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: climate, auspol, ausvotes, australians, australian","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: climate, auspol, ausvoteshealth2022, ausvotes, australians","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: auspol, australians, climate, ausvotes, politicians","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: ausvotes, auspol, australians, election, politics","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: politicians, politics, govern, election, liberal","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: auspol, renewable, nsw, australia, electricity","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: auspol, australians, aus, nsw, zealanders","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: austerity, auspol, aust, nsw, australian","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: auspol, climatefuelled, australia, australias, australians","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: emissions, auspol, australians, australia, australias"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_auspol_ausvotes_australians_politician...","x":["2022-01-17T16:24:29.763000+00:00","2022-01-26T23:20:17.849999+00:00","2022-02-05T01:53:49.700000+00:00","2022-02-14T04:27:21.550000+00:00","2022-02-23T07:00:53.400000+00:00","2022-03-04T09:34:25.249999+00:00","2022-03-13T12:07:57.100000+00:00","2022-03-22T14:41:28.950000+00:00","2022-03-31T17:15:00.800000+00:00","2022-04-09T19:48:32.649999+00:00","2022-04-18T22:22:04.500000+00:00","2022-04-28T00:55:36.350000+00:00","2022-05-07T03:29:08.200000+00:00","2022-05-16T06:02:40.049999+00:00","2022-05-25T08:36:11.900000+00:00","2022-06-03T11:09:43.750000+00:00","2022-06-12T13:43:15.600000+00:00","2022-06-21T16:16:47.449999+00:00","2022-06-30T18:50:19.300000+00:00","2022-07-09T21:23:51.150000+00:00"],"y":[6,8,5,11,11,22,18,24,14,19,17,18,29,39,10,4,12,9,12,16],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: crops, agriculture, superfood, agricultural, greenhouse","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: coffeeproducing, coffee, crops, ag ...

# %%
model.visualize_heatmap(topics = [0,1,2,3,4,5],n_clusters=5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="068446f5-c386-4cdb-849a-8932040f9a7f" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("068446f5-c386-4cdb-849a-8932040f9a7f")) {                    Plotly.newPlot(                        "068446f5-c386-4cdb-849a-8932040f9a7f",                        [{"coloraxis":"coloraxis","name":"0","x":["0_auspol_ausvotes_australians","1_agriculture_agricultural_...","2_climate_replying_change","3_volvo_ev_emissions","4_emissions_trudeaus_ontario","5_filibuster_ballot_republi..."],"y":["0_auspol_ausvotes_australians","1_agriculture_agricultural_...","2_climate_replying_change","3_volvo_ev_emissions","4_emissions_trudeaus_ontario","5_filibuster_ballot_republi..."],"z":[[0.9999997615814209,0.6560860872268677,0.6885290741920471,0.663597047328949,0.7160497903823853,0.5752390027046204],[0.6560860872268677,1.0,0.7430397272109985,0.6553316116333008,0.657448410987854,0.5227285623550415],[0.6885290741920471,0.7430397272109985,1.000000238418579,0.6904724836349487,0.7072491645812988,0.5945775508880615],[0.663597047328949,0.6553316116333008,0.6904724836349487,0.9999998807907104,0.7263344526290894,0.5559846758842468],[0.7160497903823853,0.657448410987854,0.7072491645812988,0.7263344526290894,1.0,0.5792380571365356],[0.5752390027046204,0.5227285623550415,0.5945775508880615,0.5559846758842468,0.5792380571365356,0.9999998807907104]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003eSimilarity Score: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111111111111111 ...
